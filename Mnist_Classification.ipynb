# %% [markdown]
# ### SVM Method

# %%
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.svm import SVC
import seaborn as sns

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

svm = SVC(kernel='linear')
svm.fit(X_train, y_train)

y_pred = svm.predict(X_test)

accuracy = svm.score(X_test, y_test)
print("Accuracy: ", accuracy)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy:  0.853

# %% [markdown]
# ### KNN Method

# %%
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

y_pred = knn.predict(X_test)

accuracy = knn.score(X_test, y_test)
print("Accuracy: ", accuracy)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy:  0.815

# %% [markdown]
# ### Decision Tree Classifier

# %%
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

dtc = DecisionTreeClassifier(max_depth=10)
dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)

accuracy = dtc.score(X_test, y_test)
print("Accuracy: ", accuracy)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy:  0.646

# %% [markdown]
# ### Random Forest Classifier

# %%
from tensorflow.keras.datasets import mnist
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

rfc = RandomForestClassifier(n_estimators=100, max_depth=10)
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)

accuracy = rfc.score(X_test, y_test)
print("Accuracy: ", accuracy)

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# Accuracy:  0.862

# %% [markdown]
# ### CNN Network

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape((60000, 28, 28, 1))[:1000]
X_test = X_test.reshape((10000, 28, 28, 1))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

X_train = X_train / 255.0
X_test = X_test / 255.0

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(10)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))

# 绘制 Loss 图像
ax[0].plot(history.history['loss'], label='Training Loss')
ax[0].plot(history.history['val_loss'], label='Validation Loss')
ax[0].set_title('Loss During Training')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].legend()

# 绘制 Accuracy 图像
ax[1].plot(history.history['accuracy'], label='Training Accuracy')
ax[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
ax[1].set_title('Accuracy During Training')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].legend()

plt.show()
# Out:
# Epoch 1/50
# 32/32 [==============================] - 3s 83ms/step - loss: 1.7411 - accuracy: 0.4690 - val_loss: 0.9281 - val_accuracy: 0.6960
# Epoch 2/50
# 32/32 [==============================] - 3s 84ms/step - loss: 0.5513 - accuracy: 0.8350 - val_loss: 0.5382 - val_accuracy: 0.8290
# Epoch 3/50
# 32/32 [==============================] - 3s 101ms/step - loss: 0.3554 - accuracy: 0.9070 - val_loss: 0.4181 - val_accuracy: 0.8680
# Epoch 4/50
# 32/32 [==============================] - 3s 102ms/step - loss: 0.2626 - accuracy: 0.9230 - val_loss: 0.3345 - val_accuracy: 0.8970
# Epoch 5/50
# 32/32 [==============================] - 3s 92ms/step - loss: 0.2039 - accuracy: 0.9390 - val_loss: 0.3579 - val_accuracy: 0.8870
# Epoch 6/50
# 32/32 [==============================] - 3s 109ms/step - loss: 0.1476 - accuracy: 0.9590 - val_loss: 0.3117 - val_accuracy: 0.9030
# Epoch 7/50
# 32/32 [==============================] - 4s 118ms/step - loss: 0.1087 - accuracy: 0.9710 - val_loss: 0.2400 - val_accuracy: 0.9220
# Epoch 8/50
# 32/32 [==============================] - 4s 141ms/step - loss: 0.0776 - accuracy: 0.9790 - val_loss: 0.2779 - val_accuracy: 0.9070
# Epoch 9/50
# 32/32 [==============================] - 3s 99ms/step - loss: 0.0596 - accuracy: 0.9780 - val_loss: 0.2166 - val_accuracy: 0.9350
# Epoch 10/50
# 32/32 [==============================] - 5s 144ms/step - loss: 0.0363 - accuracy: 0.9900 - val_loss: 0.2538 - val_accuracy: 0.9260
# Epoch 11/50
# 32/32 [==============================] - 5s 161ms/step - loss: 0.0217 - accuracy: 0.9950 - val_loss: 0.2248 - val_accuracy: 0.9380
# Epoch 12/50
# 32/32 [==============================] - 3s 101ms/step - loss: 0.0161 - accuracy: 0.9990 - val_loss: 0.2450 - val_accuracy: 0.9260
# Epoch 13/50
# 32/32 [==============================] - 2s 77ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9360
# Epoch 14/50
# 32/32 [==============================] - 3s 80ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.2263 - val_accuracy: 0.9360
# Epoch 15/50
# 32/32 [==============================] - 3s 90ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2430 - val_accuracy: 0.9410
# Epoch 16/50
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2322 - val_accuracy: 0.9410
# Epoch 17/50
# 32/32 [==============================] - 3s 82ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2220 - val_accuracy: 0.9480
# Epoch 18/50
# 32/32 [==============================] - 3s 83ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2299 - val_accuracy: 0.9470
# Epoch 19/50
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2342 - val_accuracy: 0.9420
# Epoch 20/50
# 32/32 [==============================] - 3s 79ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2358 - val_accuracy: 0.9470
# Epoch 21/50
# 32/32 [==============================] - 3s 84ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2401 - val_accuracy: 0.9470
# Epoch 22/50
# 32/32 [==============================] - 3s 86ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.2473 - val_accuracy: 0.9440
# Epoch 23/50
# 32/32 [==============================] - 2s 53ms/step - loss: 8.7461e-04 - accuracy: 1.0000 - val_loss: 0.2398 - val_accuracy: 0.9470
# Epoch 24/50
# 32/32 [==============================] - 2s 76ms/step - loss: 7.7351e-04 - accuracy: 1.0000 - val_loss: 0.2434 - val_accuracy: 0.9470
# Epoch 25/50
# 32/32 [==============================] - 1s 45ms/step - loss: 6.9248e-04 - accuracy: 1.0000 - val_loss: 0.2448 - val_accuracy: 0.9460
# Epoch 26/50
# 32/32 [==============================] - 2s 57ms/step - loss: 6.3394e-04 - accuracy: 1.0000 - val_loss: 0.2463 - val_accuracy: 0.9470
# Epoch 27/50
# 32/32 [==============================] - 2s 71ms/step - loss: 5.8112e-04 - accuracy: 1.0000 - val_loss: 0.2476 - val_accuracy: 0.9440
# Epoch 28/50
# 32/32 [==============================] - 3s 96ms/step - loss: 5.3595e-04 - accuracy: 1.0000 - val_loss: 0.2510 - val_accuracy: 0.9470
# Epoch 29/50
# 32/32 [==============================] - 2s 52ms/step - loss: 5.0194e-04 - accuracy: 1.0000 - val_loss: 0.2526 - val_accuracy: 0.9460
# Epoch 30/50
# 32/32 [==============================] - 1s 43ms/step - loss: 4.6845e-04 - accuracy: 1.0000 - val_loss: 0.2532 - val_accuracy: 0.9470
# Epoch 31/50
# 32/32 [==============================] - 2s 54ms/step - loss: 4.4299e-04 - accuracy: 1.0000 - val_loss: 0.2550 - val_accuracy: 0.9460
# Epoch 32/50
# 32/32 [==============================] - 2s 58ms/step - loss: 4.1703e-04 - accuracy: 1.0000 - val_loss: 0.2573 - val_accuracy: 0.9460
# Epoch 33/50
# 32/32 [==============================] - 2s 51ms/step - loss: 3.8419e-04 - accuracy: 1.0000 - val_loss: 0.2552 - val_accuracy: 0.9440
# Epoch 34/50
# 32/32 [==============================] - 2s 48ms/step - loss: 3.6048e-04 - accuracy: 1.0000 - val_loss: 0.2561 - val_accuracy: 0.9480
# Epoch 35/50
# 32/32 [==============================] - 2s 47ms/step - loss: 3.4067e-04 - accuracy: 1.0000 - val_loss: 0.2589 - val_accuracy: 0.9470
# Epoch 36/50
# 32/32 [==============================] - 2s 75ms/step - loss: 3.1544e-04 - accuracy: 1.0000 - val_loss: 0.2590 - val_accuracy: 0.9470
# Epoch 37/50
# 32/32 [==============================] - 3s 79ms/step - loss: 3.0152e-04 - accuracy: 1.0000 - val_loss: 0.2622 - val_accuracy: 0.9470
# Epoch 38/50
# 32/32 [==============================] - 3s 88ms/step - loss: 2.8250e-04 - accuracy: 1.0000 - val_loss: 0.2615 - val_accuracy: 0.9470
# Epoch 39/50
# 32/32 [==============================] - 3s 108ms/step - loss: 2.6412e-04 - accuracy: 1.0000 - val_loss: 0.2637 - val_accuracy: 0.9470
# Epoch 40/50
# 32/32 [==============================] - 3s 86ms/step - loss: 2.5341e-04 - accuracy: 1.0000 - val_loss: 0.2645 - val_accuracy: 0.9460
# Epoch 41/50
# 32/32 [==============================] - 3s 96ms/step - loss: 2.3582e-04 - accuracy: 1.0000 - val_loss: 0.2662 - val_accuracy: 0.9470
# Epoch 42/50
# 32/32 [==============================] - 3s 93ms/step - loss: 2.2397e-04 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9470
# Epoch 43/50
# 32/32 [==============================] - 3s 100ms/step - loss: 2.1057e-04 - accuracy: 1.0000 - val_loss: 0.2671 - val_accuracy: 0.9460
# Epoch 44/50
# 32/32 [==============================] - 3s 95ms/step - loss: 2.0655e-04 - accuracy: 1.0000 - val_loss: 0.2669 - val_accuracy: 0.9470
# Epoch 45/50
# 32/32 [==============================] - 2s 51ms/step - loss: 1.9779e-04 - accuracy: 1.0000 - val_loss: 0.2695 - val_accuracy: 0.9480
# Epoch 46/50
# 32/32 [==============================] - 2s 54ms/step - loss: 1.8805e-04 - accuracy: 1.0000 - val_loss: 0.2713 - val_accuracy: 0.9470
# Epoch 47/50
# 32/32 [==============================] - 2s 74ms/step - loss: 1.7391e-04 - accuracy: 1.0000 - val_loss: 0.2710 - val_accuracy: 0.9470
# Epoch 48/50
# 32/32 [==============================] - 3s 80ms/step - loss: 1.6747e-04 - accuracy: 1.0000 - val_loss: 0.2717 - val_accuracy: 0.9470
# Epoch 49/50
# 32/32 [==============================] - 2s 57ms/step - loss: 1.5854e-04 - accuracy: 1.0000 - val_loss: 0.2729 - val_accuracy: 0.9470
# Epoch 50/50
# 32/32 [==============================] - 2s 62ms/step - loss: 1.5452e-04 - accuracy: 1.0000 - val_loss: 0.2732 - val_accuracy: 0.9470

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Reshape the data for training and testing
X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

# Create DMatrix objects from the data
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Define the hyperparameters for the XGBoost model
param = {
    'max_depth': 3,
    'eta': 0.1,
    'objective': 'multi:softmax',
    'num_class': 10
}

# Train the XGBoost model
num_rounds = 50
bst = xgb.train(param, dtrain, num_rounds)

# Predict the labels for the test set
preds = bst.predict(dtest)

# Calculate the accuracy of the classifier
acc = accuracy_score(y_test, preds)
print("Accuracy: {:.2f}%".format(acc * 100))

# Plot the confusion matrix
cm = confusion_matrix(y_test, preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 2023-05-21 20:11:25.770388: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Accuracy: 82.60%

# %% [markdown]
# ### LightGBM

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Reshape the data for training and testing
X_train = X_train.reshape((60000, 28*28))[:1000]
X_test = X_test.reshape((10000, 28*28))[:1000]
y_train = y_train.astype(int)[:1000]
y_test = y_test.astype(int)[:1000]

# Create Dataset objects from the data
train_data = lgb.Dataset(X_train, label=y_train)
test_data = lgb.Dataset(X_test, label=y_test)

# Define the hyperparameters for the LightGBM model
param = {
    'max_depth': 3,
    'learning_rate': 0.1,
    'objective': 'multiclass',
    'num_class': 10
}

# Train the LightGBM model
num_rounds = 50
bst = lgb.train(param, train_data, num_rounds)

# Predict the labels for the test set
preds = bst.predict(X_test)
preds = np.argmax(preds, axis=1)

# Calculate the accuracy of the classifier
acc = accuracy_score(y_test, preds)
print("Accuracy: {:.2f}%".format(acc * 100))

# Plot the confusion matrix
cm = confusion_matrix(y_test, preds)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
# Out:
# 2023-05-21 22:54:13.771811: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.022255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 28022
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 465
# [LightGBM] [Info] Start training from score -2.333044
# [LightGBM] [Info] Start training from score -2.154165
# [LightGBM] [Info] Start training from score -2.312635
# [LightGBM] [Info] Start training from score -2.375156
# [LightGBM] [Info] Start training from score -2.253795
# [LightGBM] [Info] Start training from score -2.385967
# [LightGBM] [Info] Start training from score -2.364460
# [LightGBM] [Info] Start training from score -2.145581
# [LightGBM] [Info] Start training from score -2.441847
# [LightGBM] [Info] Start training from score -2.302585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Accuracy: 82.90%
